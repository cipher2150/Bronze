# %% [markdown]
# ## Accessing the data folder

# %%
bronze_df = (
    spark.read.parquet("/Workspace/Users/cipher2150@gmail.com/Bronze/year=2026/")
)

# %%
bronze_df.printSchema()

# %%
bronze_df.show(2000, truncate=False)
